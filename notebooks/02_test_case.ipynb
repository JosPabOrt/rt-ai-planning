# %%
import os, sys
sys.path.append("../src")

from core.build_case import build_case_from_dicom
from qa.engine import evaluate_case
from qa.checks.plan import debug_print_plan_beams
from qa.reporting import print_qa_report

data_root = "../data_raw"
patient_id = "patient_001"

ct_folder     = os.path.join(data_root, patient_id, "CT")
rtstruct_path = os.path.join(data_root, patient_id, "RTSTRUCT.dcm")
rtplan_path   = os.path.join(data_root, patient_id, "RTPLAN.dcm")
rtdose_path   = os.path.join(data_root, patient_id, "RTDOSE.dcm")

case = build_case_from_dicom(
    patient_id=patient_id,
    ct_folder=ct_folder,
    rtstruct_path=rtstruct_path,
    rtplan_path=rtplan_path,
    rtdose_path=rtdose_path,
)

debug_print_plan_beams(case)

report = evaluate_case(case)
print_qa_report(report)
# Out:
# [INFO] ROIs encontradas en RTSTRUCT:
#       (intento crear máscara; se saltan las que no tienen contornos)
#    - Probando ROI: BODY ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: CouchSurface ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: CouchInterior ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: CTV_46 ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: PROSTATA ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: PTV_46/23 ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: Bladder ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: Bowel ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: FemHeadNeck_L ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: FemHeadNeck_R ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: PenileBulb ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: Prostate ... FALLO → se omite ('Dataset' object has no attribute 'ContourSequence')
#    - Probando ROI: Rectum ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: SeminalVesicle1 ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: CTV_78 ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: PTV_78/39 ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: zPTV_46_Opti ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: zPTV_46_Opti_Int ... OK  shape original y,x,z: (211, 512, 512)
#    - Probando ROI: zAnillo 0.3 cm ... OK  shape original y,x,z: (211, 512, 512)
# [INFO] RTPLAN cargado: ../data_raw/patient_001/RTPLAN.dcm (Label=Prostata F1)
# [INFO] RTPLAN cargado: ../data_raw/patient_001/RTPLAN.dcm (Label=Prostata F1)
# [INFO] RTDOSE cargado y remuestreado: ../data_raw/patient_001/RTDOSE.dcm
#        dose_gy shape=(211, 512, 512)
# [DEBUG] Plan energy=6, technique=STATIC, num_arcs=1
# [DEBUG] Número de beams en lista: 3
#
#   Beam 1 | name=kVCBCT | modality=PHOTON | type=STATIC | is_arc=False | gantry=0.0->0.0 | couch=0.0 | collimator=0.0
#   Beam 2 | name=Field 1 | modality=PHOTON | type=DYNAMIC | is_arc=True | gantry=181.0->179.0 | couch=0.0 | collimator=350.0
#   Beam 3 | name=Field 2 | modality=PHOTON | type=DYNAMIC | is_arc=False | gantry=179.0->181.0 | couch=0.0 | collimator=10.0
#
#
# ======================================================================
#  AUTO-QA REPORT  —  Caso: patient_001
# ======================================================================
#
# Score global: 80.7 / 100
# [################----]
#
# Detalles de checks:
# ----------------------------------------------------------------------
#
# [CT]
# [OK] CT geometry consistency  (score=1.00)
#     CT con geometría consistente según configuración.
#        - shape: (211, 512, 512)
#        - spacing: (2.0, 1.171875, 1.171875)
#        - ct_profile: None
#        - config_used: {'required_dim': 3, 'min_slices': 1, 'max_slices': 1024, 'require_positive_spacing': True, 'min_slice_thickness_mm': 0.8, 'max_slice_thickness_mm': 5.0, 'min_inplane_spacing_mm': 0.3, 'max_inplane_spacing_mm': 2.5, 'score_ok': 1.0, 'score_fail': 0.3}
#
#
# [Dose]
# [OK] Dose loaded  (score=1.00)
#     Dosis cargada y consistente con el CT.
#        - dose_shape: (211, 512, 512)
#
# [FAIL] Global hotspots  (score=0.30)
#     Dmax global=303809.00 Gy (660454.3% de 46.00 Gy) > 110% permitido. V110%=24.45% del volumen. Revisar hotspots.
#        - Dmax_Gy: 303809.0
#        - prescription_Gy: 46.0
#        - rel_Dmax: 6604.54347826087
#        - V110%: 24.449906190989708
#
# [FAIL] OAR DVH (basic)  (score=0.30)
#     Se detectaron violaciones de límites DVH en uno o más OARs. Rectum V70=100.0% > 20.0% | Rectum V60=100.0% > 35.0% | Bladder V70=100.0% > 35.0% | FemHead_L Dmax=173607.0 Gy > 50.0 Gy | FemHead_R Dmax=186172.0 Gy > 50.0 Gy
#        - num_constraints: 5
#        - num_violations: 5
#        - issues: ['Rectum V70=100.0% > 20.0%', 'Rectum V60=100.0% > 35.0%', 'Bladder V70=100.0% > 35.0%', 'FemHead_L Dmax=173607.0 Gy > 50.0 Gy', 'FemHead_R Dmax=186172.0 Gy > 50.0 Gy']
#        - metrics: {'Rectum': {'V70_%': 100.0, 'V60_%': 100.0}, 'Bladder': {'V70_%': 100.0}, 'FemHead_L': {'Dmax_Gy': 173607.0}, 'FemHead_R': {'Dmax_Gy': 186172.0}}
#
# [OK] PTV coverage (D95)  (score=1.00)
#     D95(PTV)=1753.00 Gy (3810.9% de 46.00 Gy prescrito). Dmax(PTV)=303809.00 Gy. Cobertura PTV adecuada.
#        - ptv_name: PTV_46/23
#        - D95_Gy: 1753.0
#        - Dmax_Gy: 303809.0
#        - prescription_Gy: 46.0
#        - rel_D95: 38.108695652173914
#
#
# [Plan]
# [FAIL] Beam geometry  (score=0.40)
#     Número de arcos clínicos = 1 distinto del preferido (2). ; 1 arcos tienen cobertura < 300.0°.
#        - site_inferred: PROSTATE
#        - technique: STATIC
#        - num_beams_total: 3
#        - num_beams_clinical: 2
#        - num_arcs: 1
#        - couch_angles: [0.0, 0.0]
#        - collimator_angles: [350.0, 10.0]
#        - arc_coverages: [{'beam_number': 2, 'coverage_deg': 2.0}]
#        - config_used: {'min_num_arcs': 1, 'max_num_arcs': 4, 'preferred_num_arcs': 2, 'couch_expected': 0.0, 'couch_tolerance': 1.0, 'collimator_families': [(10.0, 40.0), (320.0, 350.0)], 'min_arc_coverage_deg': 300.0, 'ignore_beam_name_patterns': ['CBCT', 'KV', 'IMAGING'], 'score_ok': 1.0, 'score_warn': 0.6, 'score_fail': 0.4, 'warn_max_issues': 1}
#
# [WARN] Fractionation reasonableness  (score=0.70)
#     Fraccionamiento 46.00 Gy en 23 fracciones (≈ 2.00 Gy/fx) para sitio PROSTATE. Esquema no listado en la tabla interna de esquemas típicos; revisar guías clínicas y protocolos del servicio. Ejemplos de esquemas comunes: Moderado 60/20 (60.0 Gy / 20 fx, VMAT, HYPO-RT / EAU) | SBRT 36.25/5 (36.25 Gy / 5 fx, SBRT, Kupelian et al.) | Convencional 78/39 (78.0 Gy / 39 fx, VMAT, RTOG 0126 / NCCN)
#        - site_inferred: PROSTATE
#        - technique: STATIC
#        - total_dose_gy: 46.0
#        - num_fractions: 23
#        - dose_per_fraction_gy: 2.0
#        - matched_scheme: None
#        - closest_schemes: [{'total': 60.0, 'fx': 20, 'tech': 'VMAT', 'label': 'Moderado 60/20', 'ref': 'HYPO-RT / EAU'}, {'total': 36.25, 'fx': 5, 'tech': 'SBRT', 'label': 'SBRT 36.25/5', 'ref': 'Kupelian et al.'}, {'total': 78.0, 'fx': 39, 'tech': 'VMAT', 'label': 'Convencional 78/39', 'ref': 'RTOG 0126 / NCCN'}]
#        - scoring_config: {'dose_tol_gy': 1.0, 'fx_tol': 1.0, 'score_match': 1.0, 'score_unlisted': 0.7, 'score_no_info': 0.8, 'score_no_schemes': 0.9}
#
# [OK] Isocenter vs PTV  (score=1.00)
#     Isocentro razonablemente centrado en PTV (distancia 9.8 mm).
#        - distance_mm: 9.751191092321184
#        - ptv_name: PTV_46/23
#        - ptv_centroid_patient_mm: [1.2073635272995489, -216.98462056610447, 15.554849402939283]
#        - iso_mm: (-0.5859375, -216.22656249999, 6.0)
#        - site_inferred: PROSTATE
#        - config_used: {'max_distance_mm': 15.0, 'score_ok': 1.0, 'score_fail': 0.3}
#
# [OK] Plan technique consistency  (score=1.00)
#     Plan consistente con configuración esperada para el sitio.
#        - site_inferred: PROSTATE
#        - plan_technique: STATIC
#        - plan_energy: 6
#        - num_beams_clinical: 2
#        - num_arcs_clinical: 1
#        - allowed_techniques: ['VMAT', 'STATIC', 'IMRT', '3D-CRT']
#        - rules: {'allowed_techniques': ['VMAT', 'STATIC', 'IMRT', '3D-CRT'], 'energy_substring': '6', 'min_beams': 1, 'max_beams': 20, 'min_arcs': 1, 'max_arcs': 4, 'ignore_beam_name_patterns': ['CBCT', 'KV', 'IMAGING'], 'score_ok': 1.0, 'score_warn': 0.6, 'score_fail': 0.3}
#
#
# [Structures]
# [WARN] Duplicate structures  (score=0.80)
#     Se detectaron 1 órganos con múltiples estructuras candidatas. Se eligió una estructura primaria por órgano; revisar duplicados.
#        - site_inferred: PROSTATE
#        - primary_by_canonical: {'CTV': 'CTV_46'}
#        - duplicates: [{'canonical': 'CTV', 'primary': 'CTV_46', 'alternatives': ['CTV_78'], 'categories': ['CTV']}]
#        - config_used: {'ignore_couch_only': True, 'ignore_helpers_only': True, 'score_no_dupes': 1.0, 'score_with_dupes': 0.8}
#
# [OK] Mandatory structures present  (score=1.00)
#     Todas las estructuras obligatorias presentes (o equivalentes por nombre).
#        - site_inferred: PROSTATE
#        - present_structures: ['BODY', 'CouchSurface', 'CouchInterior', 'CTV_46', 'PROSTATA', 'PTV_46/23', 'Bladder', 'Bowel', 'FemHeadNeck_L', 'FemHeadNeck_R', 'PenileBulb', 'Rectum', 'SeminalVesicle1', 'CTV_78', 'PTV_78/39', 'zPTV_46_Opti', 'zPTV_46_Opti_Int', 'zAnillo 0.3 cm']
#        - present_groups: {'BODY': 'BODY', 'PTV': 'PTV_46/23', 'BLADDER': 'Bladder', 'RECTUM': 'Rectum', 'FEMHEAD_L': 'FemHeadNeck_L', 'FEMHEAD_R': 'FemHeadNeck_R'}
#        - missing_groups: []
#        - scoring_config: {'score_ok': 1.0, 'score_few_missing': 0.5, 'score_many_missing': 0.3}
#
# [OK] PTV inside BODY  (score=1.00)
#     PTV contenido dentro de BODY (fuera=0.000% ≤ 0.100%).
#        - site_inferred: PROSTATE
#        - ptv_name: PTV_46/23
#        - body_name: BODY
#        - num_voxels_outside: 0
#        - frac_outside: 0.0
#        - config_used: {'body_name_patterns': ['BODY', 'EXTERNAL', 'EXT', 'OUTLINE'], 'max_frac_outside': 0.001, 'score_ok': 1.0, 'score_fail': 0.1}
#
# [OK] PTV volume  (score=1.00)
#     Volumen PTV dentro de un rango razonable (1020.8 cc).
#        - ptv_name: PTV_46/23
#        - volume_cc: 1020.7781982421875
#        - limits_cc: {'min_cc': 20.0, 'max_cc': 2500.0}
#
# ======================================================================
#  RECOMENDACIONES
# ======================================================================
#  - Número de arcos clínicos = 1 distinto del preferido (2). ; 1 arcos tienen cobertura < 300.0°.
#  - La dosis máxima global supera el porcentaje de hotspot permitido. Revisa el patrón de MLC, la normalización del plan y los objetivos de homogeneidad. Considera reoptimizar reduciendo picos focales de dosis dentro del PTV o en tejidos sanos.
#
# El plan presenta regiones con dosis muy alta (hotspots) por encima del límite configurado. Valora junto con el físico si estos hotspots están dentro del PTV o en tejido sano, y si es necesario ajustar el plan antes de iniciar el tratamiento.
#  - Se encontraron violaciones de límites DVH en uno o más órganos de riesgo. Revisa en detalle los DVH de recto, vejiga y cabezas femorales, y considera reoptimizar para reducir el volumen por encima de los umbrales configurados.
#
# Uno o más órganos de riesgo exceden los límites de dosis configurados (por ejemplo, recto o vejiga). Valora con el físico si estas violaciones son aceptables en el contexto clínico del paciente o si es necesario ajustar el plan.
#
# ======================================================================
#  FIN DEL REPORTE
# ======================================================================
