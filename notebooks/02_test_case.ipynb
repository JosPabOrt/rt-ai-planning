# %%
import os, sys
sys.path.append("../src")

from core.build_case import build_case_from_dicom
from qa.engine import evaluate_case
from qa.checks.plan import debug_print_plan_beams
from qa.reporting import print_qa_report

data_root = "../data_raw"
patient_id = "patient_001"

ct_folder     = os.path.join(data_root, patient_id, "CT")
rtstruct_path = os.path.join(data_root, patient_id, "RTSTRUCT.dcm")
rtplan_path   = os.path.join(data_root, patient_id, "RTPLAN.dcm")
rtdose_path   = os.path.join(data_root, patient_id, "RTDOSE.dcm")

case = build_case_from_dicom(
    patient_id=patient_id,
    ct_folder=ct_folder,
    rtstruct_path=rtstruct_path,
    rtplan_path=rtplan_path,
    rtdose_path=rtdose_path,
)

debug_print_plan_beams(case)

report = evaluate_case(case)
print_qa_report(report)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       2 sys.path.append("../src")
#       4 from core.build_case import build_case_from_dicom
# ----> 5 from qa.engine import evaluate_case
#       6 from qa.checks.plan import debug_print_plan_beams
#       7 from qa.reporting import print_qa_report
#
# File ~/rt-ai-planning/notebooks/../src/qa/__init__.py:11
#       3 """
#       4 Paquete principal de QA.
#       5
#       6 La lógica de checks individuales vive en `qa.checks`.
#       7 El motor de evaluación de casos está en `qa.engine`.
#       8 """
#      10 # Opcional: reexportar run_all_checks si te sirve
# ---> 11 from .checks import run_all_checks  # noqa: F401
#
# File ~/rt-ai-planning/notebooks/../src/qa/checks/__init__.py:6
#       3 from typing import List
#       4 from core.case import Case, CheckResult
# ----> 6 from .ct import run_ct_checks
#       7 from .structures import run_structures_checks
#       8 from .plan import run_plan_checks
#
# File ~/rt-ai-planning/notebooks/../src/qa/checks/ct.py:9
#       6 import numpy as np
#       8 from core.case import Case, CheckResult
# ----> 9 from qa.config import (
#      10     get_ct_geometry_config,
#      11     get_ct_hu_config,
#      12     get_ct_fov_config,
#      13     get_ct_couch_config,
#      14     get_ct_clipping_config,
#      15     get_ct_recommendations,
#      16     format_recommendations_text,
#      17 )
#      20 # ============================================================
#      21 # Utilidad interna: perfil de CT
#      22 # ============================================================
#      24 def _get_ct_profile(case: Case) -> str | None:
#
# File ~/rt-ai-planning/notebooks/../src/qa/config.py:4014
#    4011 from pathlib import Path
#    4012 from typing import Optional
# -> 4014 from src.qa.config_overrides import (
#    4015     load_overrides,
#    4016     apply_overrides_to_configs,
#    4017 )
#    4020 # Esta sección define reglas para:
#    4021 #   - Normalizar pesos de secciones y checks
#    4022 #   - Aplicar defaults dinámicos según contexto (sitio / clínica / etc.)
#    4023 #   - Producir una "vista efectiva" de la config sin modificar los dicts base
#    4026 DYNAMIC_DEFAULTS_CONFIG: Dict[str, Any] = {
#    4027     # Normalizar pesos de secciones para que la suma sea 1.0
#    4028     "normalize_section_weights": True,
#    (...)
#    4044     "default_clinic_id": "DEFAULT",
#    4045 }
#
# ModuleNotFoundError: No module named 'src'
